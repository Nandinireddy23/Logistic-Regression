# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandinireddy23/Logistic-Regression/blob/main/Lr_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import seaborn as sns

# Load the Titanic dataset
train = sns.load_dataset('titanic')

# Check for typos or case sensitivity in the column name
print(train.columns)  # Print all column names

# Try accessing the column with the correct name, for example:
train["survived"].value_counts()  # Note the lowercase 's'
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x='survived', data=train)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Titanic dataset
train = sns.load_dataset('titanic')

plt.figure(figsize=(10, 8))
sns.countplot(x='survived', data=train) # Change 'Survived' to 'survived'
plt.show()

# %%
sns.countplot(x='survived', hue='pclass', data=train) # Change 'Pclass' to 'pclass'
plt.show()

# %%
train["survived"].value_counts() # Change 'Survived' to 'survived'
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x='survived',data=train)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x='survived', hue='sex', palette=["#7fcdbb","#edf8b1"], data=train)
# Out:
# <Axes: xlabel='survived', ylabel='count'>
